# %%
from hashlib import sha1
import altair as alt
import pandas as pd
import test_assignment2 as t
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\arefe\OneDrive\Documents\UBC_Data_Science\UBC-Data-Science-Assigments\ass2.ipynb Cell 1 line <module>
#       <a href='vscode-notebook-cell:/c%3A/Users/arefe/OneDrive/Documents/UBC_Data_Science/UBC-Data-Science-Assigments/ass2.ipynb#W0sZmlsZQ%3D%3D?line=1'>2</a> import altair as alt
#       <a href='vscode-notebook-cell:/c%3A/Users/arefe/OneDrive/Documents/UBC_Data_Science/UBC-Data-Science-Assigments/ass2.ipynb#W0sZmlsZQ%3D%3D?line=2'>3</a> import pandas as pd
# ----> <a href='vscode-notebook-cell:/c%3A/Users/arefe/OneDrive/Documents/UBC_Data_Science/UBC-Data-Science-Assigments/ass2.ipynb#W0sZmlsZQ%3D%3D?line=3'>4</a> import test_assignment2 as t
#
# File c:\Users\arefe\OneDrive\Documents\UBC_Data_Science\UBC-Data-Science-Assigments\test_assignment2.py:4, in <module>
#       2 import pandas as pd
# ...

# %%
df_1a=pd.read_csv("data/wine_a.csv")
df_1a
# Out:
#           Grape     Origin  Alcohol    pH Colour   Aroma
# 0    Chardonnay  Australia    14.23  3.51  White  Floral
# 1  Pinot Grigio      Italy    13.20  3.30  White  Fruity
# 2   Pinot Blanc     France    13.16  3.16  White  Citrus
# 3        Shiraz      Chile    14.91  3.39    Red   Berry
# 4        Malbec  Argentina    13.83  3.28    Red  Fruity

# %%
df_1b=pd.read_csv("data/wine_b.csv")
df_1b
# Out:
#   My wine diary Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0         Grape     Origin    Alcohol         pH     Colour      Aroma
# 1    Chardonnay  Australia      14.23       3.51      White     Floral
# 2  Pinot Grigio      Italy       13.2        3.3      White     Fruity
# 3   Pinot Blanc     France      13.16       3.16      White     Citrus
# 4        Shiraz      Chile      14.91       3.39        Red      Berry
# 5        Malbec  Argentina      13.83       3.28        Red     Fruity
#
#    Unnamed: 6
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN

# %%
df_1b = pd.read_csv("data/wine_b.csv", skiprows=1)
df_1b
# Out:
#           Grape     Origin  Alcohol    pH Colour   Aroma
# 0    Chardonnay  Australia    14.23  3.51  White  Floral
# 1  Pinot Grigio      Italy    13.20  3.30  White  Fruity
# 2   Pinot Blanc     France    13.16  3.16  White  Citrus
# 3        Shiraz      Chile    14.91  3.39    Red   Berry
# 4        Malbec  Argentina    13.83  3.28    Red  Fruity

# %%
df_1d = pd.read_csv("data/wine_d.txt", delimiter="\t")
df_1d
# Out:
#           Grape     Origin  Alcohol    pH Colour   Aroma
# 0    Chardonnay  Australia    14.23  3.51  White  Floral
# 1  Pinot Grigio      Italy    13.20  3.30  White  Fruity
# 2   Pinot Blanc     France    13.16  3.16  White  Citrus
# 3        Shiraz      Chile    14.91  3.39    Red   Berry
# 4        Malbec  Argentina    13.83  3.28    Red  Fruity

# %%
df_1e = pd.read_csv("data/wine_e.csv").drop(columns="Add more columns")
df_1e
# Out:
#           Grape     Origin  Alcohol    pH Colour   Aroma
# 0    Chardonnay  Australia    14.23  3.51  White  Floral
# 1  Pinot Grigio      Italy    13.20  3.30  White  Fruity
# 2   Pinot Blanc     France    13.16  3.16  White  Citrus
# 3        Shiraz      Chile    14.91  3.39    Red   Berry
# 4        Malbec  Argentina    13.83  3.28    Red  Fruity
